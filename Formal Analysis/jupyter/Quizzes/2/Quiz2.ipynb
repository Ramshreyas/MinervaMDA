# %%
library(Matching)
# Out:
# Warning message:
# "package 'Matching' was built under R version 4.0.2"
# Loading required package: MASS
#
# ##
# ##  Matching (Version 4.9-7, Build Date: 2020-02-05)
# ##  See http://sekhon.berkeley.edu/matching for additional documentation.
# ##  Please cite software as:
# ##   Jasjeet S. Sekhon. 2011. ``Multivariate and Propensity Score Matching
# ##   Software with Automated Balance Optimization: The Matching package for R.''
# ##   Journal of Statistical Software, 42(7): 1-52.
# ##

# %%
?GerberGreenImai
# Out:
# GerberGreenImai            package:Matching            R Documentation
#
# i
#
# n:
#
#      This is the dataset used by Imai (2005) to replicate and evaluate
#      the field experiment done by Gerber and Green (2000). The
#      accompanying demo replicates Imai's propensity score model which
#      is then used to estimate the causal effect of get-out-the-vote
#      telephone calls on turnout.
#
# e:
#
#      data(GerberGreenImai)
#
# t:
#
#      A data frame with 10829 observations on the following 26
#      variables.
#
#      PERSONS Number persons in household
#
#      WARD Ward of residence
#
#      QUESTION Asked to commit to voting
#
#      MAILGRP Sent mail
#
#      PHONEGRP Phone batch \#1
#
#      PERSNGRP Personal contact attempted
#
#      APPEAL Content of message
#
#      CONTACT Personal contact occurred
#
#      MAILINGS Number of mailings sent
#
#      AGE Age of respondent
#
#      MAJORPTY Democratic or Republican
#
#      VOTE96.0 Abstained in 1996
#
# ...

# %%
data(GerberGreenImai)

# %%
head(GerberGreenImai)
# Out:
#      PERSONS WARD QUESTION MAILGRP PHONEGRP PERSNGRP APPEAL CONTACT MAILINGS
# 1221 2       13   0        0       1        0        3      0       0
# 1228 2       24   1        0       1        0        3      0       0
# 1236 2       29   1        0       1        0        2      0       0
# 1242 2       10   1        0       1        0        2      0       0
# 1279 2       21   0        0       1        0        2      0       0
# 1289 2       20   1        0       1        0        3      0       0
#      AGE ... DIS.MC DIS.PHN PHN.C PHNTRT1 PHNTRT2 PHN.C1 PHN.C2 NEW phone AGE2
# 1221 74  ... 99     1       1     1       1       1      1      0   1     54.76
# 1228 37  ... 99     1       1     1       1       1      1      0   1     13.69
# 1236 24  ... 99     1       1     1       1       1      1      0   1      5.76
# 1242 81  ... 99     1       1     1       1       1      1      0   1     65.61
# ...

# %%
#What are the dimensions of the data set (how many rows and columns)?
dim(GerberGreenImai)
# Out:
# [1] 10829    26

# %%
#What are the variable names?
names(GerberGreenImai)
# Out:
#  [1] "PERSONS"  "WARD"     "QUESTION" "MAILGRP"  "PHONEGRP" "PERSNGRP"
#  [7] "APPEAL"   "CONTACT"  "MAILINGS" "AGE"      "MAJORPTY" "VOTE96.0"
# [13] "VOTE96.1" "MAILCALL" "VOTED98"  "PHNSCRPT" "DIS.MC"   "DIS.PHN"
# [19] "PHN.C"    "PHNTRT1"  "PHNTRT2"  "PHN.C1"   "PHN.C2"   "NEW"
# [25] "phone"    "AGE2"

# %%
#Is there any missing data? If so, how many elements are missing.. 
table(is.na(GerberGreenImai))

#..and which rows contain the missing data?
rownames(is.na(GerberGreenImai))
# Out:
#  FALSE
# 281554
#     [1] "1221"  "1228"  "1236"  "1242"  "1279"  "1289"  "1312"  "1314"  "1319"
#    [10] "1320"  "1321"  "1322"  "1327"  "1328"  "1331"  "1335"  "1342"  "1350"
#    [19] "1351"  "1359"  "1368"  "1369"  "1375"  "1398"  "1414"  "1421"  "1424"
#    [28] "1425"  "1429"  "1430"  "1460"  "1462"  "1464"  "1478"  "1481"  "1534"
#    [37] "1539"  "1543"  "1545"  "1549"  "1559"  "1566"  "1587"  "1590"  "1594"
#    [46] "1597"  "1617"  "1629"  "1631"  "1639"  "1641"  "1655"  "1692"  "1693"
#    [55] "1720"  "1721"  "1728"  "1731"  "1737"  "1742"  "1777"  "1778"  "1789"
#    [64] "1790"  "1814"  "1815"  "1816"  "1818"  "1819"  "1824"  "1825"  "1826"
#    [73] "1830"  "1832"  "1838"  "1839"  "1840"  "1844"  "1845"  "1846"  "1849"
#    [82] "1851"  "1855"  "1856"  "1857"  "1858"  "1859"  "1860"  "1862"  "1863"
#    [91] "1866"  "1867"  "1869"  "1870"  "1879"  "1880"  "1882"  "1887"  "1888"
#   [100] "1890"  "1891"  "1892"  "1894"  "1895"  "1897"  "1899"  "1900"  "1901"
# ...

# %%
#In this data set, each column is a variable (e.g., “AGE”, “WARD”, etc.). Which of these variables (if any) is a factor?
           
names(Filter(is.factor, GerberGreenImai))
# Out:
# [1] "WARD"

# %%
#Code a for loop that outputs column name and variable type

sapply(GerberGreenImai, class)
# Out:
#   PERSONS      WARD  QUESTION   MAILGRP  PHONEGRP  PERSNGRP    APPEAL   CONTACT
# "integer"  "factor" "integer" "integer" "integer" "integer" "integer" "integer"
#  MAILINGS       AGE  MAJORPTY  VOTE96.0  VOTE96.1  MAILCALL   VOTED98  PHNSCRPT
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#    DIS.MC   DIS.PHN     PHN.C   PHNTRT1   PHNTRT2    PHN.C1    PHN.C2       NEW
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "numeric"
#     phone      AGE2
# "numeric" "numeric"

# %% [markdown]
# #What do you think the variable AGE2 represents?
#
# AGE2 is the square of the age of the residents divided by 100.

# %%
#Which individuals (and how many) voted in 1998?

rownames(na.omit(subset(GerberGreenImai, VOTE96.1 == TRUE)))
# Out:
#    [1] "1221"  "1228"  "1236"  "1242"  "1312"  "1319"  "1320"  "1321"  "1327"
#   [10] "1328"  "1331"  "1342"  "1351"  "1359"  "1368"  "1369"  "1375"  "1398"
#   [19] "1414"  "1421"  "1424"  "1425"  "1429"  "1460"  "1462"  "1464"  "1478"
#   [28] "1481"  "1534"  "1539"  "1543"  "1545"  "1559"  "1566"  "1587"  "1590"
#   [37] "1594"  "1597"  "1617"  "1629"  "1631"  "1641"  "1655"  "1692"  "1693"
#   [46] "1720"  "1721"  "1728"  "1731"  "1742"  "1777"  "1778"  "1789"  "1814"
#   [55] "1816"  "1819"  "1825"  "1826"  "1830"  "1832"  "1838"  "1839"  "1840"
#   [64] "1845"  "1851"  "1855"  "1860"  "1866"  "1867"  "1879"  "1882"  "1888"
#   [73] "1894"  "1897"  "1899"  "1900"  "1917"  "1918"  "1922"  "1936"  "1943"
#   [82] "1944"  "1945"  "1946"  "1949"  "1951"  "1952"  "1955"  "1956"  "1964"
#   [91] "1969"  "1970"  "1971"  "1972"  "1973"  "1979"  "1982"  "1983"  "1996"
#  [100] "2000"  "2001"  "2006"  "2007"  "2020"  "2023"  "2032"  "2038"  "2040"
# ...

# %%
nrow(na.omit(subset(GerberGreenImai, VOTE96.1 == TRUE)))
# Out:
# [1] 5793

# %%
#Which individuals (and how many) have age > 35 and did NOT vote in 1998?

rownames(subset(subset(GerberGreenImai, AGE > 35), VOTED98 == FALSE))
# Out:
#    [1] "1228"  "1328"  "1350"  "1414"  "1424"  "1629"  "1639"  "1728"  "1731"
#   [10] "1737"  "1742"  "1777"  "1789"  "1790"  "1832"  "1839"  "1846"  "1857"
#   [19] "1859"  "1862"  "1869"  "1888"  "1891"  "1894"  "1897"  "1903"  "1917"
#   [28] "1918"  "1923"  "1925"  "1932"  "1933"  "1937"  "1955"  "1956"  "1963"
#   [37] "1964"  "1972"  "1979"  "1980"  "1983"  "1996"  "2003"  "2017"  "2020"
#   [46] "2021"  "2023"  "2028"  "2029"  "2050"  "2067"  "2068"  "2070"  "2072"
#   [55] "2078"  "2080"  "2084"  "2089"  "2092"  "2100"  "2111"  "2113"  "2114"
#   [64] "2116"  "2118"  "2120"  "2136"  "2161"  "2187"  "2188"  "2191"  "2194"
#   [73] "2196"  "2201"  "2206"  "2207"  "2210"  "2212"  "2216"  "2220"  "2228"
#   [82] "2231"  "2232"  "2241"  "2245"  "2248"  "2251"  "2262"  "2264"  "2266"
#   [91] "2271"  "2275"  "2292"  "2298"  "2301"  "2305"  "2309"  "2325"  "2337"
#  [100] "2346"  "2403"  "2404"  "2406"  "2410"  "2427"  "2435"  "2446"  "2451"
# ...

# %%
nrow(subset(subset(GerberGreenImai, AGE > 35), VOTED98 == FALSE))
# Out:
# [1] 3662

# %% [markdown]
# What line of code eliminates all rows that satisfy the conditions of Question 8?
#
# GerberGreenImai[-c(subset(subset(GerberGreenImai, AGE > 35), VOTED98 == FALSE))]

# %%
#Append a column that records a 1 if Question 8’s conditions satisfy, 0 if not.

GerberGreenImai$Q8TRUE <- ifelse((GerberGreenImai$AGE > 35) & GerberGreenImai$VOTED98, 1, 0)

head(GerberGreenImai)
# Out:
#      PERSONS WARD QUESTION MAILGRP PHONEGRP PERSNGRP APPEAL CONTACT MAILINGS
# 1221 2       13   0        0       1        0        3      0       0
# 1228 2       24   1        0       1        0        3      0       0
# 1236 2       29   1        0       1        0        2      0       0
# 1242 2       10   1        0       1        0        2      0       0
# 1279 2       21   0        0       1        0        2      0       0
# 1289 2       20   1        0       1        0        3      0       0
#      AGE ... DIS.PHN PHN.C PHNTRT1 PHNTRT2 PHN.C1 PHN.C2 NEW phone AGE2  Q8TRUE
# 1221 74  ... 1       1     1       1       1      1      0   1     54.76 1
# 1228 37  ... 1       1     1       1       1      1      0   1     13.69 0
# 1236 24  ... 1       1     1       1       1      1      0   1      5.76 0
# 1242 81  ... 1       1     1       1       1      1      0   1     65.61 1
# 1279 34  ... 1       1     1       1       1      1      1   1     11.56 0
# ...

# %%
#Write a function that performs the algorithm you identiﬁed in Question 6

agesquared <- function(age) {(age ^ 2)/100}
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
